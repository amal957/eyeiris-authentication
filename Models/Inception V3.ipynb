# %%
import numpy as np
import cv2
import os
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Input, concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Set the plotting style globally
plt.style.use('seaborn-darkgrid')

# Step 1: Data Loading
def load_images_and_masks(dataset_dir, target_size=(128, 128)):
    images, masks = [], []
    
    print(f"Starting data loading from: {dataset_dir}")
    
    # Loop through folders 001 to 223
    for folder_num in range(1, 224):
        folder_name = f"{folder_num:03d}"  # Format as 001, 002, etc.
        folder_path = os.path.join(dataset_dir, folder_name)
        
        # Check if folder exists
        if not os.path.exists(folder_path):
            print(f"Skipping folder {folder_name} - does not exist at {folder_path}")
            continue
        
        try:
            # Get all image files (.bmp) in the current folder
            image_files = [f for f in os.listdir(folder_path) if f.lower().endswith('.bmp')]
            
            if not image_files:
                print(f"No .bmp files found in folder {folder_name}")
                continue
                
            print(f"Processing folder {folder_name} - Found {len(image_files)} images")
            
            for image_file in image_files:
                try:
                    # Load image (.bmp format)
                    image_path = os.path.join(folder_path, image_file)
                    image = cv2.imread(image_path)
                    
                    # Load corresponding mask (.png format)
                    mask_file = image_file.replace('.bmp', '.png')
                    mask_path = os.path.join(folder_path, mask_file)
                    
                    if not os.path.exists(mask_path):
                        print(f"Missing mask file for {image_file} in {folder_name}")
                        continue
                        
                    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
                    
                    if image is None:
                        print(f"Failed to load image: {image_path}")
                        continue
                    if mask is None:
                        print(f"Failed to load mask: {mask_path}")
                        continue
                    
                    # Resize images and masks
                    image = cv2.resize(image, target_size)
                    mask = cv2.resize(mask, target_size)
                    
                    # Normalize the data
                    images.append(img_to_array(image) / 255.0)
                    masks.append(img_to_array(mask) / 255.0)
                    
                    if len(images) % 10 == 0:
                        print(f"Processed {len(images)} images...")
                        
                except Exception as e:
                    print(f"Error processing {image_file} in {folder_name}: {str(e)}")
                    continue
                    
        except Exception as e:
            print(f"Error processing folder {folder_name}: {str(e)}")
            continue
    
    if not images:
        raise ValueError("No images were successfully loaded!")
    
    # Convert to numpy arrays
    images_array = np.array(images)
    masks_array = np.array(masks)
    
    print(f"\nFinished loading:")
    print(f"Total images loaded: {len(images)}")
    print(f"Images shape: {images_array.shape}")
    print(f"Masks shape: {masks_array.shape}")
    
    return images_array, masks_array

def inception_module(x, filters):
    """
    Basic Inception module implementation
    """
    # 1x1 convolution
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu')(x)
    
    # 3x3 convolution with 1x1 reduction
    conv3x3_reduce = Conv2D(filters[1], (1, 1), padding='same', activation='relu')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu')(conv3x3_reduce)
    
    # 5x5 convolution with 1x1 reduction
    conv5x5_reduce = Conv2D(filters[3], (1, 1), padding='same', activation='relu')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu')(conv5x5_reduce)
    
    # Max pooling with 1x1 projection
    pool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters[5], (1, 1), padding='same', activation='relu')(pool)
    
    # Concatenate all branches
    return concatenate([conv1x1, conv3x3, conv5x5, pool_proj], axis=3)

def InceptionUNet(input_shape=(128, 128, 3), num_classes=1):
    inputs = Input(input_shape)
    
    # Encoder path
    # First Inception block
    inc1 = inception_module(inputs, [32, 48, 64, 8, 16, 16])  # First set of filter sizes
    pool1 = MaxPooling2D(pool_size=(2, 2))(inc1)
    pool1 = Dropout(0.1)(pool1)
    
    # Second Inception block
    inc2 = inception_module(pool1, [64, 96, 128, 16, 32, 32])
    pool2 = MaxPooling2D(pool_size=(2, 2))(inc2)
    pool2 = Dropout(0.1)(pool2)
    
    # Third Inception block
    inc3 = inception_module(pool2, [128, 192, 256, 32, 64, 64])
    pool3 = MaxPooling2D(pool_size=(2, 2))(inc3)
    pool3 = Dropout(0.2)(pool3)
    
    # Bottleneck
    bottleneck = inception_module(pool3, [256, 384, 512, 64, 128, 128])
    bottleneck = Dropout(0.3)(bottleneck)
    
    # Decoder path
    # First upsampling block
    up6 = UpSampling2D(size=(2, 2))(bottleneck)
    up6 = Conv2D(256, (2, 2), padding='same', activation='relu')(up6)
    merge6 = concatenate([inc3, up6], axis=3)
    dec6 = inception_module(merge6, [128, 192, 256, 32, 64, 64])
    dec6 = Dropout(0.2)(dec6)
    
    # Second upsampling block
    up7 = UpSampling2D(size=(2, 2))(dec6)
    up7 = Conv2D(128, (2, 2), padding='same', activation='relu')(up7)
    merge7 = concatenate([inc2, up7], axis=3)
    dec7 = inception_module(merge7, [64, 96, 128, 16, 32, 32])
    dec7 = Dropout(0.1)(dec7)
    
    # Third upsampling block
    up8 = UpSampling2D(size=(2, 2))(dec7)
    up8 = Conv2D(64, (2, 2), padding='same', activation='relu')(up8)
    merge8 = concatenate([inc1, up8], axis=3)
    dec8 = inception_module(merge8, [32, 48, 64, 8, 16, 16])
    dec8 = Dropout(0.1)(dec8)
    
    # Final convolution
    final = Conv2D(num_classes, (1, 1), activation='sigmoid')(dec8)
    
    model = Model(inputs=inputs, outputs=final)
    return model

# Metrics
def dice_coefficient(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    """
    Combines dice loss and binary crossentropy
    """
    dice = dice_loss(y_true, y_pred)
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    return dice * 0.5 + bce * 0.5

def iou(y_true, y_pred, smooth=1):
    y_true = tf.cast(y_true > 0.5, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return (intersection + smooth) / (union + smooth)

# Training function
def train_model(model, X_train, y_train, X_val, y_val, epochs=70, batch_size=8):
    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss=combined_loss,
        metrics=['accuracy', dice_coefficient, iou]
    )
    
    # Learning rate scheduler
    def lr_schedule(epoch):
        initial_lr = 1e-4
        if epoch < 30:
            return initial_lr
        elif epoch < 50:
            return initial_lr * 0.1
        else:
            return initial_lr * 0.01
    
    callbacks = [
        # Learning rate scheduler
        tf.keras.callbacks.LearningRateScheduler(lr_schedule),
        
        # Model checkpointing
        tf.keras.callbacks.ModelCheckpoint(
            'best_model.keras',
            monitor='val_dice_coefficient',
            mode='max',
            save_best_only=True,
            verbose=1
        ),
        
        # Early stopping
        tf.keras.callbacks.EarlyStopping(
            monitor='val_dice_coefficient',
            mode='max',
            patience=10,
            restore_best_weights=True,
            verbose=1
        ),
        
        # TensorBoard logging
        tf.keras.callbacks.TensorBoard(
            log_dir='./logs',
            histogram_freq=1,
            write_graph=True
        )
    ]

    # Train the model
    print("Starting model training...")
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=1
    )
    
    return model, history

# Visualization functions
def visualize_results(model, X_val, y_val, num_samples=5):
    for i in np.random.randint(0, len(X_val), num_samples):
        original_image = X_val[i]
        ground_truth_mask = y_val[i].squeeze()
        predicted_mask = model.predict(np.expand_dims(original_image, axis=0)).squeeze()
        
        iou_score = iou(ground_truth_mask, predicted_mask).numpy()
        dice_score = dice_coefficient(ground_truth_mask, predicted_mask).numpy()
        
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))
        fig.suptitle(f'Sample {i+1} - IoU: {iou_score:.2f}, Dice: {dice_score:.2f}', fontsize=14)
        
        axes[0].imshow(original_image)
        axes[0].set_title('Original Image')
        axes[0].axis('off')
        
        axes[1].imshow(ground_truth_mask, cmap='gray')
        axes[1].set_title('Ground Truth Mask')
        axes[1].axis('off')
        
        im = axes[2].imshow(predicted_mask > 0.5, cmap='gray')
        axes[2].set_title('Predicted Mask')
        axes[2].axis('off')
        
        plt.colorbar(im, ax=axes[2], fraction=0.046, pad=0.04)
        plt.tight_layout()
        plt.show()

def plot_training_history(history):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    ax1.plot(history.history['loss'], label='Training Loss')
    ax1.plot(history.history['val_loss'], label='Validation Loss')
    ax1.set_title('Model Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend(loc='upper right')
    
    ax2.plot(history.history['accuracy'], label='Training Accuracy')
    ax2.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax2.set_title('Model Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.legend(loc='lower right')
    
    ax3.plot(history.history['dice_coefficient'], label='Training Dice')
    ax3.plot(history.history['val_dice_coefficient'], label='Validation Dice')
    ax3.set_title('Dice Coefficient')
    ax3.set_xlabel('Epoch')
    ax3.set_ylabel('Dice Coefficient')
    ax3.legend(loc='lower right')
    
    ax4.plot(history.history['iou'], label='Training IoU')
    ax4.plot(history.history['val_iou'], label='Validation IoU')
    ax4.set_title('IoU Score')
    ax4.set_xlabel('Epoch')
    ax4.set_ylabel('IoU')
    ax4.legend(loc='lower right')
    
    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    # Set random seed for reproducibility
    tf.random.set_seed(42)
    np.random.seed(42)
    
    # Step 1: Load and preprocess data
    dataset_dir = "/kaggle/input/iitd-iris/Masks and Images"  # Update with your dataset path
    images, masks = load_images_and_masks(dataset_dir)
    print("Data loaded. Images shape:", images.shape, "Masks shape:", masks.shape)
    
    # Step 2: Split data
    X_train, X_val, y_train, y_val = train_test_split(
        images, masks, 
        test_size=0.2, 
        random_state=42
    )
    print("Data split. Training set:", X_train.shape, y_train.shape)
    print("Validation set:", X_val.shape, y_val.shape)
    
    # Step 3: Create and compile model
    model = InceptionUNet(input_shape=(128, 128, 3), num_classes=1)
    model.summary()
    
    # Step 4: Train model
    trained_model, history = train_model(
        model=model,
        X_train=X_train,
        y_train=y_train,
        X_val=X_val,
        y_val=y_val,
        epochs=70,
        batch_size=8
    )
    
    # Step 5: Save the trained model
    print("\nSaving final model...")
    trained_model.save('final_model.keras')
    print("Model saved as 'final_model.keras'")
    
    # Save training history
    print("Saving training history...")
    np.save('training_history.npy', history.history)
    print("Training history saved as 'training_history.npy'")
    
    # Step 6: Visualize results
    print("\nGenerating visualization of results...")
    visualize_results(trained_model, X_val, y_val, num_samples=5)
    
    # Step 7: Plot training history
    print("\nPlotting training history...")
    plot_training_history(history)
    
    # Step 8: Final evaluation
    print("\nEvaluating final model on validation set...")
    evaluation = trained_model.evaluate(
        X_val, 
        y_val, 
        verbose=1
    )
    
    # Print final metrics
    print("\nFinal Evaluation Metrics:")
    metrics = ['Loss', 'Accuracy', 'Dice Coefficient', 'IoU']
    for metric, value in zip(metrics, evaluation):
        print(f"{metric}: {value:.4f}")

# Helper functions for model loading and prediction
def load_saved_model(model_path='final_model.keras'):
    """
    Load a saved model with custom metrics
    """
    return tf.keras.models.load_model(
        model_path,
        custom_objects={
            'dice_coefficient': dice_coefficient,
            'dice_loss': dice_loss,
            'iou': iou,
            'combined_loss': combined_loss
        }
    )

def predict_with_saved_model(image_path, model_path='final_model.keras'):
    """
    Make a prediction using a saved model
    
    Parameters:
    -----------
    image_path : str
        Path to the input image
    model_path : str
        Path to the saved model
        
    Returns:
    --------
    numpy.ndarray
        Predicted segmentation mask
    """
    # Load the model
    model = load_saved_model(model_path)
    
    # Load and preprocess the image
    image = cv2.imread(image_path)
    image = cv2.resize(image, (128, 128))
    image = img_to_array(image) / 255.0
    image = np.expand_dims(image, axis=0)
    
    # Make prediction
    prediction = model.predict(image)
    
    return prediction

# Example usage of prediction function
def process_single_image(image_path, model_path='final_model.keras'):
    """
    Process a single image and display results
    
    Parameters:
    -----------
    image_path : str
        Path to the input image
    model_path : str
        Path to the saved model
    """
    # Load and preprocess image
    image = cv2.imread(image_path)
    original_size = image.shape[:2]
    
    # Resize for model
    image_resized = cv2.resize(image, (128, 128))
    image_normalized = img_to_array(image_resized) / 255.0
    
    # Make prediction
    model = load_saved_model(model_path)
    prediction = model.predict(np.expand_dims(image_normalized, axis=0))[0]
    
    # Resize prediction back to original size
    prediction_resized = cv2.resize(prediction, (original_size[1], original_size[0]))
    
    # Visualize
    plt.figure(figsize=(15, 5))
    
    plt.subplot(131)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title('Original Image')
    plt.axis('off')
    
    plt.subplot(132)
    plt.imshow(prediction[..., 0], cmap='gray')
    plt.title('Predicted Mask (Model Size)')
    plt.axis('off')
    
    plt.subplot(133)
    plt.imshow(prediction_resized[..., 0], cmap='gray')
    plt.title('Predicted Mask (Original Size)')
    plt.axis('off')
    
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-1-59ca5d2ec48a>:14: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
# Starting data loading from: /kaggle/input/iitd-iris/Masks and Images
# Processing folder 001 - Found 10 images
# Processed 10 images...
# Processing folder 002 - Found 10 images
# Processed 20 images...
# Processing folder 003 - Found 10 images
# Processed 30 images...
# Processing folder 004 - Found 10 images
# Processed 40 images...
# Processing folder 005 - Found 10 images
# Processed 50 images...
# Processing folder 006 - Found 10 images
# Processed 60 images...
# Processing folder 007 - Found 10 images
# Processed 70 images...
# Processing folder 008 - Found 10 images
# Processed 80 images...
# Processing folder 009 - Found 10 images
# ...

# %%
def plot_training_history(hist):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss
    ax1.plot(history.history['loss'], label='Training Loss', color='darkblue')
    ax1.plot(history.history['val_loss'], label='Validation Loss', color='red')
    ax1.set_title('Model Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend(loc='upper right')
    
    # Accuracy
    ax2.plot(history.history['accuracy'], label='Training Accuracy', color='darkblue')
    ax2.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
    ax2.set_title('Model Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.legend(loc='lower right')
    
    # Dice Coefficient
    ax3.plot(history.history['dice_coefficient'], label='Training Dice', color='darkblue')
    ax3.plot(history.history['val_dice_coefficient'], label='Validation Dice', color='red')
    ax3.set_title('Dice Coefficient')
    ax3.set_xlabel('Epoch')
    ax3.set_ylabel('Dice Coefficient')
    ax3.legend(loc='lower right')
    
    # IoU Score
    ax4.plot(history.history['iou'], label='Training IoU', color='darkblue')
    ax4.plot(history.history['val_iou'], label='Validation IoU', color='red')
    ax4.set_title('IoU Score')
    ax4.set_xlabel('Epoch')
    ax4.set_ylabel('IoU')
    ax4.legend(loc='lower right')
    
    plt.tight_layout()
    plt.show()
hist='/kaggle/working/training_history.npy'
plot_training_history(hist)
